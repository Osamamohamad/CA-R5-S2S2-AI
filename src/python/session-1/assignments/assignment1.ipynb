# %% [markdown]
# Input Validation

# %%
email="Amit_ml.@gmail.edu"
if email.find("@") != 0 and email.find(".") > email.find("@"):
    print("Valid email ")
else:
    print("Invalid email ")
# Out:
# Valid email
